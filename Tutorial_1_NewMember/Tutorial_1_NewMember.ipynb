# %% [markdown]
# # How to: Set up required tools as a new member of Neuro-iX
#
# **Learning outcomes**
#
# 0. [MonETS account setup](#scrollTo=be524736-3944-4376-b03c-6b85ffb0eb3e)
# 1. [Help updating Neuro-iX.github.io with your information](#scrollTo=9f94af8c-5dce-4327-9580-793e7aaecc22)
# 2. [New account to access Narval's compute nodes and Neuro-iX's Github](#scrollTo=3877d880-4c49-4093-9b69-3cdfe6462132) \
#     a) [Create an account on GitHub and Compute Canada Database (CCDB)](#scrollTo=3877d880-4c49-4093-9b69-3cdfe6462132) \
#     b) [Configure your ssh connexion to Narval cluster and GitHub repository](#scrollTo=80d1a788-1996-4b38-8775-1aa50e7cb509) \
# 4. [Setup Miniconda, Git, Datalad and Jupyterlab on your laptop](#scrollTo=37d0971e-0a67-499d-b194-3d630dedabfe) \
#     a) [Understand Miniconda, Git, DataLad and JupyterLab](#scrollTo=37d0971e-0a67-499d-b194-3d630dedabfe) \
#     b) [Install Miniconda, Git, DataLad and JupyterLab](#scrollTo=7adc9993-6b01-45ea-9102-d86d571db932) \
#     c) [Basics for Git, DataLad, JupyterLab and GitHub in bash](#scrollTo=3efb0745-22dd-4835-9b94-8f3d69387b39)
# 5. [Setup a virtual machine on your laptop](#scrollTo=edd34488-e440-4f79-b2c2-7d843d491e03)
# 6. [Bonus: Some interesting applications and websites](#scrollTo=6a2582c2-01ed-4b8a-8dd4-56320de0635c)

# %% [markdown]
# <a id='scrollTo=be524736-3944-4376-b03c-6b85ffb0eb3e'></a>
# ## 0. MonETS account setup
# - **Use google translate for french to english translation of a web page:** \
# https://translate.google.com/?hl=fr&sl=fr&tl=en&op=websites
#
# - **Connect to one of those three WIFI networks:** \
# "ETS-Campus" for internet and other ressources only at ÉTS \
# "ETS-Invites" for internet only at ÉTS \
# "EDUROAM" for internet in **every student places in Montréal** \
# Username: email address (e.g., jean.tremblay.1@ens.etsmtl.ca OR jean.tremblay@etsmtl.ca). \
# Password (same as monETS): as defined in your **admission letter** or the one you have chosen during your registration. \
# To request assistance, contact the Registrar's Office : room **A-1120, accueilbdr@etsmtl.ca, 514-396-8888**. \
# Methode: PEAP  \
# (Authentication: MSCHAPV2)  \
# CA certificate: "Trust on first use" or "Do not validate" \
# Domain: **etsmtl.ca** \
# Documentation: https://www.etsmtl.ca/services/sti/catalogue-de-services/reseau/wifi#Wifi_Android
#
# - **Configure the multifactor authentication for your monETS account:** \
# https://portail.etsmtl.ca/
#
# - **Get your ID card:** \
# https://www.etsmtl.ca/en/student-experience/student-life
#     1. Uploading an ID photo of you on “Uploading your photo” page here: https://portail.etsmtl.ca/
#     2. If your documents are in order, you’ll receive a confirmation email and your student card will either be mailed to you, or be available for pickup at the Prevention and Safety Office, Access Management, in Room A-0135.
#
#     For trainees:
#     1. Contact your professor to verify that your application is complete.
#     2. He or she will contact your host department to request access to the premise
#     3. Make an appointment by e-mail at gestion-locaux@etsmtl.ca to have your photo taken and obtain your access card.
#
#     After getting your ID card, send a picture of it to **sylvain.bouix@etsmtl.ca**, so that Sylvain requested you the access to the labs A-3413 and A-3434.
#
# - **Configure the VPN:** \
# https://www.etsmtl.ca/services/sti/catalogue-de-services/reseau/etablir-connexion-vpn?lang=en-ca
#
# - **Get access to your Onedrive data server and Outlook mailbox:** \
# http://office365.etsmtl.ca
#
# - **Prepare for the weekly JournalClub:** \
# Ask link for the Google doc and Onedrive shared folder at **benoit.verreman@etsmtl.ca**
#
# - **Join the Discord:** \
# Stay tunned by joining the lab's Discord (send an invitation to **benv333**): https://discord.com/
#
# - **Helpers in case of personnal problem or dispute:** \
# **SVE (psychological services and more)** (E-3040, +15143968942): https://www.etsmtl.ca/experience-etudiante/appui-a-la-reussite/soutien-psychologique \
# **BRP (Respectful Campus Office)**: https://www.etsmtl.ca/en/about-ets/bureau-du-respect-de-la-personne
#
# - **Discover the softwares you can get from ETS (optional):** \
# https://www.etsmtl.ca/activites-et-services-aux-etudiants/soutiens-documentaire-technologique-et-entrepreneurial/soutien-technologique#Outils-d'apprentissage  \
#
# - **Be aware and understand the different codes of conduct (optional):** \
# ÉTS Integrity and Responsible Conduct in Research: https://www.etsmtl.ca/en/research/studying-in-research/contribute-to-the-advancement-of-graduate-level-research/research-ethics-committee \
# Ethics of AI (University of Helsinki): https://ethics-of-ai.mooc.fi/

# %% [markdown]
# <a id='scrollTo=9f94af8c-5dce-4327-9580-793e7aaecc22'></a>
# ## 1. Help updating Neuro-iX.github.io with your information
#
# - **Visit our website:** \
# https://neuro-ix.github.io
#
# - **Complete this Google Form for updating the website with your professionnal information:**  \
# https://forms.gle/ED53rp24KYCZtMYu7
#
# - **Send a selfie of yours for the website (you can do it at a later time):**  \
# https://forms.gle/mcd3XNGQHgiMPYBAA

# %% [markdown]
# <a id='scrollTo=3877d880-4c49-4093-9b69-3cdfe6462132'></a>
# ## 2. New account to access Narval's compute nodes and Neuro-iX's Github
# ### a) Create an account on GitHub and Compute Canada Database (CCDB)
# **Register and/or share your GitHub:**
# 1. Create a new account: https://github.com/signup?ref_cta=Sign+up&ref_loc=header+logged+out&ref_page=%2F&source=header-home
# 2. Send me your GitHub username (handle) at **benoit.verreman@etsmtl.ca** or on Discord (**benv333**).  \
# To change your username on GitHub: top right corner > Settings > Account
#
# **Register on CCDB (for access to computing server Narval):**
# 1. Create a new account: https://ccdb.alliancecan.ca/security/login  \
# a. Click on register  \
# b. Tick the agreements (you can say no to the optional ones)  \
# c. Account application: No  \
# d. Institution: **Calcul Québec: École de technologie supérieure**  \
# c. Department: **Département de génie logiciel et des technologies de l'information**  \
# d. CCRI number (after ticking Position): **bqy-284-01**
# 2. Ask **Sylvain Bouix** at **sylvain.bouix@etsmtl.ca** or on Discord (**sylvain0830**) to validate your new CCDB account.

# %% [markdown]
# <a id='scrollTo=80d1a788-1996-4b38-8775-1aa50e7cb509'></a>
# ### b) Configure your ssh connexion to Narval cluster and GitHub repository
# - **Install a toolbox for remote computing:**  \
# Ideally, you should have both Windows and Linux/macOS using a [virtual machine](#scrollTo=edd34488-e440-4f79-b2c2-7d843d491e03).  \
# If you are on Windows, you can install [**MobaXterm**](https://mobaxterm.mobatek.net/download-home-edition.html).  \
# Alternatively, use a terminal (with **ssh**) or other toolboxes for remote computing like [**Putty**](https://numato.com/blog/how-to-install-putty-on-linux/) (Windows/Linux), **Royal TSX** (Windows/macOS) or **OpenSSH** (Windows/Linux/macOS).
#
# - **Configure the multifactor authentication for CCDB (Duo Mobile app):** \
# https://ccdb.alliancecan.ca/multi_factor_authentications
#
# - **Set up a ssh key for your CCDB account and GitHub (with a passphrase preferably):** \
# https://docs.alliancecan.ca/wiki/SSH_Keys \
# https://docs.github.com/en/authentication/connecting-to-github-with-ssh/adding-a-new-ssh-key-to-your-github-account?platform=linux
#
# - **Protect your ssh keys and activate your private key (in every new terminal):**
#
# **In Windows Powershell:**
# ```bash
# cd ~/.ssh
# start .
# right-click object > properties > security #protect writing rights
# dir ~/.ssh
# eval $(ssh-agent -s)
# ssh-add ~/.ssh/PrivateKey #file without format .pub
# ```
# **In Linux terminal:**
# ```bash
# ls -la ~/.ssh
# chmod 700 ~/.ssh -R
# ls -la ~/.ssh
# eval $(ssh-agent -s)
# ssh-add ~/.ssh/PrivateKey #file without format .pub
# ```
#
# - **Create a new session on MobaXterm:**
#
# ![Configuration of new session on MobaXterm](mobaxterm_ConfigSessionNarval.png)
#
# In Sessions -> New session: \
# The remote host is **narval.calculcanada.ca** OR **narval.alliancecan.ca**. \
# Use your **CCDB username** and select your **private ssh key file**. \
# Change **SSH-Browser type to SCP** (enhanced OR normal) to enter Duo mobile code (multifactor authentication) only once.
#
# - **Create a new session on Putty:**  \
# Host Name: **narval.calculcanada.ca** OR **narval.alliancecan.ca** \
# Connextion type: SSH \
# Fonts -> Font used for ordinary text -> Change -> Monospace (or something else) \
# Data -> Auto-login username: your CCDB username \
# SSH -> X11 -> Check Enable X11 forwarding \
# SSH -> Auth -> Add your private key file for authentication \
# Session -> Saved sessions: myNarvalSession -> Save
#
# **For further presentation of Narval, see [Tutorial-3](https://colab.research.google.com/github/Neuro-iX/Tutorials/blob/main/Tutorial_3_Narval_CCDB/Tutorial_3_Narval.ipynb).**

# %% [markdown]
# <a id='scrollTo=37d0971e-0a67-499d-b194-3d630dedabfe'></a>
# ## 3. Setup Miniconda, Git, DataLad and JupyterLab on your laptop
# ### a) Understand Miniconda, Git, DataLad and JupyterLab
# - **Underestand Miniconda:**  \
# Miniconda is a free minimal installer for conda. It is a small bootstrap version of Anaconda that includes only conda, Python, the packages they both depend on, and a small number of other useful packages (like pip, zlib, and a few others).  \
# Documentation: https://docs.conda.io/en/latest/miniconda.html
#
# - **Underestand Git:**  \
# Git is a free and open source distributed version control system designed to handle everything from small to very large projects with speed and efficiency.   \
# Documentation: https://git-scm.com/doc
#
# - **Underestand DataLad:**  \
# DataLad is a general purpose tool for managing everything involved in the digital workflow of using data – regardless of the data's type, content and size.
#
# ![Datalad overview](diagram_overview_datalad.png)
#
# Fig. Schematic difference between the Git and git-annex aspect of your dataset, and where each part usually gets published to.
#
# Documentation: https://handbook.datalad.org/en/latest/basics/101-138-sharethirdparty.html  \
# Cheat sheet: https://handbook.datalad.org/en/latest/basics/101-136-cheatsheet.html#cheat
#
# - **Underestand JupyterLab:**  \
# JupyterLab is a highly extensible, feature-rich notebook authoring application and editing environment, and is a part of Project Jupyter, a large umbrella project centered around the goal of providing tools (and standards) for interactive computing with computational notebooks.  \
# Documentation: https://jupyterlab.readthedocs.io/en/latest/

# %% [markdown]
# <a id='scrollTo=7adc9993-6b01-45ea-9102-d86d571db932'></a>
# ### b) Install Miniconda, Git, DataLad and JupyterLab
# - **Install Miniconda depending on your OS:**  \
# https://docs.conda.io/en/latest/miniconda.html \
# Alternatively, you can install Anaconda (bigger software): \
# https://docs.anaconda.com/free/anaconda/install/linux/
#
# - **Install Git depending on your OS:**  \
# https://github.com/git-guides/install-git \
# Or simply with conda:
# ```bash
# conda install -c conda-forge git
# ```
#
# - **Install DataLad depending on your OS:**  \
# https://handbook.datalad.org/en/latest/intro/installation.html# \
# Or simply with conda:
# ```bash
# conda install -c conda-forge datalad
# ```
#
# - **Install JuperterLab depending on your OS:**  \
# https://jupyterlab.readthedocs.io/en/stable/getting_started/installation.html \
# Or simply with conda:
# ```bash
# conda install -c conda-forge jupyterlab
# ```

# %% [markdown]
# <a id='scrollTo=3efb0745-22dd-4835-9b94-8f3d69387b39'></a>
# ### c) Basics for Git, DataLad, JupyterLab and GitHub in bash
# - **Configure Git and create a new dataset (new folder with version control) with DataLad:**
# ```bash
# git config --global user.name "GithubUsername" #Replace by your own Github information account
# git config --global user.email "GithubEmailAddress" #Replace by your own Github information account
# datalad create -c text2git ~/Documents/new-dataset #Add --force if the folder already exist
# cd ~/Documents/new-dataset
# git config --local user.name "GithubUsername" #Replace by your own Github information account
# git config --local user.email "GithubEmailAddress" #Replace by your own Github information account
# git config --list --local
# ```
#
# - **Example of how you should launch a command in your dataset:**
# ```bash
# datalad run -i MyNewFile -m "Created new file" touch {inputs[0]}
# #automatically save when using 'datalad run'
# ```
#
# More complexe example, but do not try:
#
# ```bash
# datalad run \
# -i surf/rh.orig -i autodet-new.gw.stats.rh.dat -i brainsupermasked.mgz -i mri/aseg.presurf.mgz -i wmsupermasked.mgz \
# -o rh.ribbon_masked.pial \
# -m "Apply command mris_place_surface from Freesurfer 7.4.1" \
# mris_place_surface --i {inputs[0]} --o {outputs} --nsmooth 1 --adgws-in {inputs[1]} --pial --rh --repulse-surf {inputs[0]} --invol {inputs[2]} --seg {inputs[3]} --threads 6 --wm {inputs[4]} --white-surf {inputs[0]}
# ```
#
# - **To overwrite files, you sometimes need to unlock them after each backup:**
# ```bash
# datalad unlock *
# mv MyNewFile MyNewFile2
# datalad status
# datalad save -m "Changed the name to MyNewFile2"
# datalad status
# ```
#
# - **On Linux, check tree structure and previous commands, and remove the dataset:**
# ```bash
# tree #May have to install it
# tig #Press 'Enter key' to see details and 'q' to exit
# cd ..
# datalad remove -d ~/Documents/new-dataset
# ```
# - **Never forget to activate your ssh key in each terminal before accessing GitHub:**
# ```bash
# eval $(ssh-agent -s)
# ssh-add ~/.ssh/PrivateKey #Change to your key name with a format different from .pub
# ```
#
# - **Create a fork of 'Neuro-iX/Tutorials' on GitHub:**  \
# On https://github.com/Neuro-iX/Tutorials, click on 'fork' and create your own fork.
#
# - **Clone GitHub repository 'GitHubUsername/Tutorials' locally:**
# ```bash
# cd ~/Documents
# git clone git@github.com:GitHubusername/Tutorials.git #Replace GitHubusername by your GitHub username
# cd Tutorials
# git config --local user.name "GithubUsername" #Replace by your own Github information account
# git config --local user.email "GithubEmailAddress" #Replace by your own Github information account
# #datalad create -c text2git --force #Optional
# ```
#
# - **Check if updates on GitHub repository and merge it with your local dataset:**
# ```bash
# git fetch origin
# alias graph='git log --all --decorate --oneline --graph'
# graph
# git merge origin/main
# graph
# ```
#
# - **Add your name at the end of this tutorial using JupyterLab, save changes locally, and update the GitHub repository:**
# ```bash
# jupyter lab #Launch JupyterLab, press 'Ctrl+C' and 'y+Enter' to quit
# datalad status
# #git add *
# #git commit -m "Unnecessary"
# datalad save -m "Explain changes"
# graph
# git push origin main
# graph
# ```
#
# - **Add a pull request from your fork to the main one on GitHub** \
# On https://github.com/Neuro-iX/Tutorials, click on 'Pull requests' ->  'New pull request' -> 'Compare across forks', select your fork, and submit. \
# Benoit or Sylvain will then review your pull request.
#
# - **After any change of the original fork, update your own fork:**
# ```bash
# git remote add upstream git@github.com:Neuro-iX/Tutorials.git
# git fetch upstream
# git checkout main
# git rebase upstream/main #rewrite history of your fork's main branch
# ```

# %% [markdown]
# <a id='scrollTo=edd34488-e440-4f79-b2c2-7d843d491e03'></a>
# ## 4. Setup a virtual machine on your laptop
# - **Use a virutal machine manager like VMWare Workstation Player (Windows/Linux):** \
# https://www.vmware.com/ca/products/workstation-player.html
#
# - **Download an OS image for the future virtual machine:** \
#     **For Linux, you can use Ubuntu 22.04.3 LTS:** \
#   https://ubuntu.com/download/desktop
#
#     **For Windows, you can use Windows 11:** \
#   https://www.microsoft.com/en-ca/software-download/windows11

# %% [markdown]
# <a id='scrollTo=6a2582c2-01ed-4b8a-8dd4-56320de0635c'></a>
# ## 5. Bonus: Some interesting applications and websites
# - **Knowledge management software:** \
# Obsidian: https://obsidian.md/ \
# Anki: https://apps.ankiweb.net/ \
# Cerego: https://www.cerego.com/
#
# - **Reference management software:** \
# Endnote: https://endnote.com/?language=en \
# Zotero: https://www.zotero.org/ \
# Mendeley: https://www.mendeley.com/autoupdates/installers/1.19.5
#
# - **Typesetting software:** \
# Overleaf: https://www.etsmtl.ca/activites-et-services-aux-etudiants/soutiens-documentaire-technologique-et-entrepreneurial/soutien-technologique#Outils-d'apprentissage
#
# - **Productivity applications:** \
# Forest: https://www.forestapp.cc/ \
# Habitica: https://habitica.com/static/home
